# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
features = pd.read_csv(r'C:\Users\aksha\PycharmProjects\FinalProject_WorkingCopy\FinalFeatures.csv')
print(features.head())
features.hist(figsize=(40,30),bins = 50)
plt.show()
correlation_matrix = features.corr()
print(correlation_matrix)
print(correlation_matrix['Z_Score_HelpfulVotes'].sort_values())
# Out:
#          Date  Stars  Helpful Votes  Z_Score_HelpfulVotes  Words  \
# 0  10/15/2018      3            837             -0.235881    565
# 1  10/15/2018      5            374              0.915696    162
# 2  10/15/2018      4            263              1.491485    343
# 3  10/17/2018      4            200              5.522007    730
# 4  10/16/2018      5            247              0.339908    194
#
#    Z_Score_Words  Paragraphs  No.break tags  Percentage_Upper_Case  \
# 0       6.453577           1              0                      3
# 1       1.394079           3              4                      3
# 2       3.666459           4              6                      4
# 3       8.525083          11             20                      3
# 4       1.795826           2              1                      6
#
#    Percentage_Lower_Case  Avg_len_paragraph_per_review
# 0                     93                   3087.000000
# 1                     91                    300.000000
# ...

# %%
plt.scatter(features['Z_Score_HelpfulVotes'],features['Paragraphs'],alpha=0.3)
plt.xlabel('Z_Score_HelpfulVotes')
plt.ylabel('Paragraphs')
# Out:
# Text(0,0.5,'Paragraphs')

# %%
plt.scatter?

# %%
from sklearn.cluster import KMeans

# %%
features_wo_dates = features.drop(['Date'],axis = 1)
features_wo_dates.head()
# Out:
#    Stars  Helpful Votes  Z_Score_HelpfulVotes  Words  Z_Score_Words  \
# 0      3            837             -0.235881    565       6.453577
# 1      5            374              0.915696    162       1.394079
# 2      4            263              1.491485    343       3.666459
# 3      4            200              5.522007    730       8.525083
# 4      5            247              0.339908    194       1.795826
#
#    Paragraphs  No.break tags  Percentage_Upper_Case  Percentage_Lower_Case  \
# 0           1              0                      3                     93
# 1           3              4                      3                     91
# 2           4              6                      4                     90
# 3          11             20                      3                     91
# 4           2              1                      6                     91
#
#    Avg_len_paragraph_per_review
# 0                   3087.000000
# 1                    300.000000
# ...

# %%
kmeans = KMeans(n_clusters = 2)
kmeans_result = kmeans.fit_transform(features_wo_dates)

# %%
kmeans.cluster_centers_
# Out:
# array([[  4.48968951e+00,   4.57777952e-01,  -1.44471291e-02,
#           3.49731457e+01,  -2.15344870e-01,   1.41677121e+00,
#           6.20275992e-01,   4.79978830e+00,   9.05032539e+01,
#           1.29693959e+02],
#        [  3.98725986e+00,   5.96885743e+00,   7.45232294e-02,
#           1.60976744e+02,   1.11082243e+00,   1.72275025e+00,
#           1.25702730e+00,   3.11263903e+00,   9.29904954e+01,
#           5.99290897e+02]])

# %%
kmeans.labels_.view()
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
plt.scatter(kmeans_result[:,0],kmeans_result[:,1],c=kmeans.labels_,cmap='rainbow',alpha=0.3)
