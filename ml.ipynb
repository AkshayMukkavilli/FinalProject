# %%
import numpy as np

# %%
a = np.array([1,2,3])
np.exp(a)
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692])

# %%
import os 
import tarfile 
from six.moves import urllib
DOWNLOAD_ROOT="https://github.com/ageron/handson-ml/tree/master/"
HOUSING_PATH="datasets/housing" 
HOUSING_URL=DOWNLOAD_ROOT+HOUSING_PATH+"/housing.tgz"
def fetch_housing_data(housing_url=HOUSING_URL,housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
        tgz_path = os.path.join(housing_path,"housing.tgz")
        urllib.request.urlretrieve(housing_url,tgz_path)
        housing_tgz = tarfile.open(tgz_path)
        housing_tgz.extractall(path=housing_path)
        housing_tgz.close()
fetch_housing_data()
# Out:
# None

# %%
import pandas as pd

def load_features(): 
    return pd.read_csv('FinalFeatures.csv')

# %%
features = load_housing_data()
features.head()
# features_with_index = features.reset_index()
# features_with_index.head()
# Out:
#          Date  Stars  Helpful Votes  Z_Score_HelpfulVotes  Words  \
# 0  10/15/2018      3            837             -0.235881    565
# 1  10/15/2018      5            374              0.915696    162
# 2  10/15/2018      4            263              1.491485    343
# 3  10/17/2018      4            200              5.522007    730
# 4  10/16/2018      5            247              0.339908    194
#
#    Z_Score_Words  Paragraphs  No.break tags  Percentage_Upper_Case  \
# 0       6.453577           1              0                      3
# 1       1.394079           3              4                      3
# 2       3.666459           4              6                      4
# 3       8.525083          11             20                      3
# 4       1.795826           2              1                      6
#
#    Percentage_Lower_Case  Avg_len_paragraph_per_review
# 0                     93                   3087.000000
# 1                     91                    300.000000
# ...

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30453 entries, 0 to 30452
# Data columns (total 11 columns):
# Date                            30453 non-null object
# Stars                           30453 non-null int64
# Helpful Votes                   30453 non-null int64
# Z_Score_HelpfulVotes            30453 non-null float64
# Words                           30453 non-null int64
# Z_Score_Words                   30453 non-null float64
# Paragraphs                      30453 non-null int64
# No.break tags                   30453 non-null int64
# Percentage_Upper_Case           30453 non-null int64
# Percentage_Lower_Case           30453 non-null int64
# Avg_len_paragraph_per_review    30453 non-null float64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 2.6+ MB

# %%
features['Paragraphs'].value_counts()
# Out:
# 1      25909
# 2       1895
# 3        962
# 4        524
# 5        335
# 6        206
# 7        155
# 8         89
# 9         86
# 10        64
# 11        52
# 12        34
# 13        34
# 14        21
# 16        18
# 15        17
# 21         7
# 19         7
# 20         4
# 18         3
# 17         3
# 22         3
# 24         3
# 29         3
# 23         3
# 37         2
# 30         2
# 28         1
# 96         1
# 46         1
# 33         1
# 50         1
# 34         1
# 57         1
# 41         1
# 51         1
# 115        1
# 25         1
# 127        1
# Name: Paragraphs, dtype: int64

# %%
features.describe()
# Out:
#               Index         Stars  Helpful Votes  Z_Score_HelpfulVotes  \
# count  30453.000000  30453.000000   30453.000000          3.045300e+04
# mean    6788.409221      4.408104       1.352675         -2.971072e-15
# std     4337.434535      1.159602      41.787228          1.000016e+00
# min        0.000000      1.000000       0.000000         -2.580916e-01
# 25%     2869.000000      4.000000       0.000000         -2.580916e-01
# 50%     6676.000000      5.000000       0.000000         -2.111979e-01
# 75%    10482.000000      5.000000       0.000000         -2.111979e-01
# max    15305.000000      5.000000    4999.000000          4.560639e+01
#
#               Words  Z_Score_Words    Paragraphs  No.break tags  \
# count  30453.000000   3.045300e+04  30453.000000   30453.000000
# mean      55.433783  -6.341410e-16      1.466457       0.723673
# std       90.431023   1.000016e+00      2.083766       3.060984
# min        1.000000  -6.708992e-01      1.000000       0.000000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
features.hist(figsize=(40,30), bins = 50)
plt.show()

# %%
Akshay
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-124babf55293> in <module>()
# ----> 1 Akshay
#
# NameError: name 'Akshay' is not defined

# %%
from sklearn.model_selection import train_test_split
training_data,test_data = train_test_split(features, test_size = 0.2, random_state = 42)

# %%
training_data.count()
# Out:
# Date                            24362
# Stars                           24362
# Helpful Votes                   24362
# Z_Score_HelpfulVotes            24362
# Words                           24362
# Z_Score_Words                   24362
# Paragraphs                      24362
# No.break tags                   24362
# Percentage_Upper_Case           24362
# Percentage_Lower_Case           24362
# Avg_len_paragraph_per_review    24362
# dtype: int64

# %%
test_data.count()
# Out:
# Date                            6091
# Stars                           6091
# Helpful Votes                   6091
# Z_Score_HelpfulVotes            6091
# Words                           6091
# Z_Score_Words                   6091
# Paragraphs                      6091
# No.break tags                   6091
# Percentage_Upper_Case           6091
# Percentage_Lower_Case           6091
# Avg_len_paragraph_per_review    6091
# dtype: int64

# %%
correlation_matrix = features.corr()

# %%
correlation_matrix
# Out:
#                                  Stars  Helpful Votes  Z_Score_HelpfulVotes  \
# Stars                         1.000000      -0.030387             -0.086754
# Helpful Votes                -0.030387       1.000000              0.176715
# Z_Score_HelpfulVotes         -0.086754       0.176715              1.000000
# Words                        -0.201059       0.148101              0.567230
# Z_Score_Words                -0.171453       0.190505              0.621161
# Paragraphs                   -0.107188       0.129681              0.925435
# No.break tags                -0.118316       0.148665              0.906607
# Percentage_Upper_Case         0.039829      -0.003022             -0.028155
# Percentage_Lower_Case        -0.021794      -0.001863             -0.057450
# Avg_len_paragraph_per_review -0.188041       0.031974             -0.016699
#
#                                  Words  Z_Score_Words  Paragraphs  \
# ...

# %%
correlation_matrix['Helpful Votes'].sort_values(ascending=True)
# Out:
# Stars                          -0.030387
# Percentage_Upper_Case          -0.003022
# Percentage_Lower_Case          -0.001863
# Avg_len_paragraph_per_review    0.031974
# Paragraphs                      0.129681
# Words                           0.148101
# No.break tags                   0.148665
# Z_Score_HelpfulVotes            0.176715
# Z_Score_Words                   0.190505
# Helpful Votes                   1.000000
# Name: Helpful Votes, dtype: float64

# %%
correlation_matrix['Stars'].sort_values(ascending=True)
# Out:
# Words                          -0.201059
# Avg_len_paragraph_per_review   -0.188041
# Z_Score_Words                  -0.171453
# No.break tags                  -0.118316
# Paragraphs                     -0.107188
# Z_Score_HelpfulVotes           -0.086754
# Helpful Votes                  -0.030387
# Percentage_Lower_Case          -0.021794
# Percentage_Upper_Case           0.039829
# Stars                           1.000000
# Name: Stars, dtype: float64

# %%
# from pandas.tools.plotting import scatter_matrix
# import pandas.plotting.scatter_matrix
from pandas.plotting import scatter_matrix
scatter_matrix(features,figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF00D57128>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CF07770470>]], dtype=object)
